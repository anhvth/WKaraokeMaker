# %%
cd /training/
# Out:
# /training

# %%
from kmaker.data import *
DS = 'public'
def play_result(path):
    name = get_name(path)
    audio_path = glob(f'data/{DS}*/songs/{name}.*')[0]
    return ItemAudioLabel(path, audio_path)

# %%
it.path, it.audio_file
# Out:
# ('./outputs/public_with_masked_text/submission/37303234365f3231.json',
#  'data/public_test/songs/37303234365f3231.wav')

# %%
names = os.listdir(f'outputs/{DS}_with_masked_text/submission/')
name = names[6]
it = play_result(f'./outputs/{DS}_with_masked_text/submission/{name}')
play_audio(it.audio)
it.play('word')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Trăng 0.074 0.476
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# cô 0.473 0.778
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# đơn 0.75 1.122
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# lặng 1.082 1.405
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# lẽ 1.396 1.727
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Nhớ 1.727 2.096
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ai 2.102 2.358
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# qua 2.341 2.651
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# từng 2.652 3.0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Góc 3.004 3.31
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# phố 3.299 3.612
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ngày 3.602 4.021
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# xưa 4.011 5.07
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Nghe 5.101 5.454
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# trong 5.472 5.823
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# tim 5.841 6.155
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# vụn 6.145 6.466
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# vỡ 6.452 6.896
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Bao 6.886 7.347
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# lần 7.337 7.706
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# nát 7.701 8.045
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# tan 7.998 8.618
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# vì 8.631 8.989
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ai 8.983 10.136
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Có 10.204 10.654
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ai 10.641 10.895
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# nhớ 10.892 11.18
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ngày 11.176 11.444
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Xưa 11.445 11.746
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# em 11.747 12.019
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ơi 12.012 12.556
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Giờ 12.564 12.815
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# đã 12.827 13.098
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# xa 13.08 13.304
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# tôi 13.295 13.598
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# mất 13.597 13.913
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# rồi 13.89 15.225
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Ánh 15.279 15.541
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# trăng 15.539 15.766
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sáng 15.747 16.202
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Lòng 16.201 16.538
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# anh 16.572 16.788
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# em 16.809 17.08
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ơi 17.072 17.448
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Giờ 17.454 17.791
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# thấm 17.781 18.144
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ướt 18.154 18.309
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# IPython.display.display_html()
# Out:
# <function IPython.core.display.display_html(*objs, **kwargs)>

# %%
from IPython.display import Video

Video("outputs/video/private_submit_version/3131393833335f30.mp4")
# Out:
# <video src="outputs/video/private_submit_version/3131393833335f30.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# from IPython.display import HTML

# HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/S_f2qV2_U00?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')

# %%
cat data/private_test/labels/37333031395f3731.json
# Out:
# [{"s": 0, "e": 0, "l": [{"s": 0, "e": 0, "d": "Trái"}, {"s": 0, "e": 0, "d": "sầu"}]}, {"s": 0, "e": 0, "l": [{"s": 0, "e": 0, "d": "Hạ"}, {"s": 0, "e": 0, "d": "buồn"}, {"s": 0, "e": 0, "d": "này..."}]}, {"s": 0, "e": 0, "l": [{"s": 0, "e": 0, "d": "Nhớ"}, {"s": 0, "e": 0, "d": "mãi"}, {"s": 0, "e": 0, "d": "ngàn"}, {"s": 0, "e": 0, "d": "sau…"}]}]

# %%
cat outputs/private_submit_version/submission/37333031395f3731.json
# Out:
# [{"s": 22, "e": 1585, "l": [{"s": 22, "e": 518, "d": "Tr\u00e1i"}, {"s": 462, "e": 1585, "d": "s\u1ea7u"}]}, {"s": 1586, "e": 2968, "l": [{"s": 1586, "e": 1987, "d": "H\u1ea1"}, {"s": 1941, "e": 2460, "d": "bu\u1ed3n"}, {"s": 2433, "e": 2968, "d": "n\u00e0y..."}]}, {"s": 2971, "e": 11386, "l": [{"s": 2971, "e": 3456, "d": "Nh\u1edb"}, {"s": 3476, "e": 3933, "d": "m\u00e3i"}, {"s": 4039, "e": 6289, "d": "ng\u00e0n"}, {"s": 6506, "e": 11386, "d": "sau\u2026"}]}]
